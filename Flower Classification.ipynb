# %% [markdown]
# # Flower Classification with Transfer Learning

# %% [markdown]
# The pictures are divided into five classes: chamomile, tulip, rose, sunflower, dandelion.
#
# For each class there are about 800 photos. Photos are not high resolution, about 320x240 pixels. Photos are not reduced to a single size, they have different proportions!

# %% [markdown]
# ### Import Required Libraries and Modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
from skimage.transform import resize
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow_hub as hub
from tensorflow.keras import Sequential, layers, applications
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ### Collect Image Paths for Each Flower Category (daisy,dandelion,rose,sunflower,tulip)

# %%
daisy = glob('daisy/*.jpg')
dandelion = glob('dandelion/*.jpg')
rose = glob('rose/*.jpg')
sunflower = glob('sunflower/*.jpg')
tulip = glob('tulip/*.jpg')

# %% [markdown]
# ### Define Classes and Corresponding Labels

# %%
classes = {0: 'daisy', 1: 'dandelion', 2: 'rose', 3: 'sunflower', 4: 'tulip'}

# %% [markdown]
# ### Load and Label Images for Each Flower Category

# %%
images = []
labels = []

for i in daisy:
    img = plt.imread(i)
    images.append(img)
    labels.append(0)

for i in dandelion:
    img = plt.imread(i)
    images.append(img)
    labels.append(1)

for i in rose:
    img = plt.imread(i)
    images.append(img)
    labels.append(2)

for i in sunflower:
    img = plt.imread(i)
    images.append(img)
    labels.append(3)

for i in tulip:
    img = plt.imread(i)
    images.append(img)
    labels.append(4)

# %% [markdown]
# ### Plot first few images

# %%
plt.figure(figsize=(10, 8))
for i in range(12):
    plt.subplot(4, 4, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(classes[labels[i]])
plt.tight_layout()

# %% [markdown]
# ### Shuffle the images

# %%
images,labels = shuffle(images,labels)

# %% [markdown]
# ### Plot some of the image after the shuffle

# %%
plt.figure(figsize=(10, 8))
for i in range(12):
    plt.subplot(4, 4, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(classes[labels[i]])
plt.tight_layout()

# %% [markdown]
# ### Resize Images to MobileNetV2 Input Shape (224,224,3)

# %%
X = []

for i in images:
    X.append(resize(i, (224,224,3)))

# %% [markdown]
# ### Plot some of the images after resizing

# %%
plt.figure(figsize=(10, 8))
for i in range(12):
    plt.subplot(4, 4, i+1)
    plt.imshow(X[i], cmap='gray')
    plt.title(classes[labels[i]])
plt.tight_layout()

# %% [markdown]
# ### Convert image and label datatypes from list to Numpy array

# %%
X = np.array(X)
y = np.array(labels)

# %% [markdown]
# ### Convert Images and Labels to NumPy Arrays

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %% [markdown]
# ### MobileNetV2 Pre-trained Feature Extractor Model URL
# * "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

# %%
feature_extractor_model = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

# %% [markdown]
# ### Load Pre-trained MobileNetV2 Feature Extractor Model

# %%
hub.load(feature_extractor_model)
# Out:
# <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject at 0x1d60e2b1450>

# %% [markdown]
# ### Define Number of Output Classes

# %%
num_of_classes = 5

# %% [markdown]
# ### Instantiate MobileNetV2 without Top Layer as Feature Extractor

# %%
pretrained_model_without_top_layer = hub.KerasLayer(
    feature_extractor_model, input_shape = (224,224,3), trainable = False
)

# %% [markdown]
# ### Build Transfer Learning Model using MobileNetV2 Feature Extractor

# %%
model = Sequential([
    pretrained_model_without_top_layer,
    layers.Dense(64, activation = 'relu'),
    layers.Dropout(0.1),
    
    layers.Dense(14, activation = 'relu'),
    layers.Dense(num_of_classes, activation = 'softmax')
])

# %% [markdown]
# ### Compile Transfer Learning Model

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Train the model

# %%
X_train = X_train.astype('float32')

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
model.fit(X_train,y_train, epochs = 10, validation_split = 0.05)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 model.fit(X_train,y_train, epochs = 10, validation_split = 0.05)
#
# File ~\desktop\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\desktop\Lib\site-packages\tensorflow\python\framework\constant_op.py:90, in convert_to_eager_tensor(value, ctx, dtype)
#      70 """Converts the given `value` to an `EagerTensor`.
#      71
#      72 Note that this function could return cached copies of created constants for
#    (...)
#      84   TypeError: if `dtype` is not compatible with the type of t.
#      85 """
#      86 if isinstance(value, np.ndarray):
#      87   # Make a copy explicitly because the EagerTensor might share the underlying
#      88   # memory with the input array. Without this copy, users will be able to
#      89   # modify the EagerTensor after its creation by changing the input array.
# ---> 90   value = value.copy()
#      91 if isinstance(value, ops.EagerTensor):
#      92   if dtype is not None and value.dtype != dtype:
#
# MemoryError: Unable to allocate 1.84 GiB for an array with shape (3280, 224, 224, 3) and data type float32

# %% [markdown]
# ### Model Prediction on Test Data

# %%
y_pred = model.predict(X_test)
# Out:
# 27/27 [==============================] - 19s 515ms/step

# %%
y_pred = [np.argmax(i) for i in y_pred]

# %% [markdown]
# ### Calculate Accuracy Score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8738425925925926

# %% [markdown]
# ### Plot confusion matrix on heatmap

# %%
sns.heatmap(confusion_matrix(y_test,y_pred), annot = True, fmt = 'd')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Print classification report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       157
#            1       0.92      0.92      0.92       213
#            2       0.96      0.74      0.83       167
#            3       0.84      0.92      0.88       144
#            4       0.77      0.91      0.83       183
#
#     accuracy                           0.87       864
#    macro avg       0.88      0.87      0.87       864
# weighted avg       0.88      0.87      0.87       864

# %% [markdown]
# ***
